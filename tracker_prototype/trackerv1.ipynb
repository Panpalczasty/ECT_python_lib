# %%
import tracker as tr
import ect
import matplotlib.pyplot as plt
import numpy as np

loader = tr.FilepathLoader()

matcher = tr.BasicMatcher(
    # transformer = transformer
    bp_thresh = 0.00001
)

tracker = tr.BasicTracker(
    template_path="../sample_imgs/black_e.png",
    matcher=matcher
)
tracker.setup()

# %%
e_filepaths = [
    "../sample_imgs/black_e_small.png",
    "../sample_imgs/black_e_4.png",
    "../sample_imgs/black_e.png",
    "../sample_imgs/black_e_3.png",
    "../sample_imgs/black_e_big.png",
    "../sample_imgs/black_e_90deg.png",
    "../sample_imgs/white.png",
    "../sample_imgs/whitenoise.png",
    "../sample_imgs/e_template.png",
    "../sample_imgs/text.png"
]

for e in e_filepaths:

    e_img = loader.load(e)

    tracker.match(e_img)
    tracker.show_result(e.split("/")[-1])
# Out:
# radius=0, shift=-1.5707963267948966, value=-0.413744-0.910393j
# radius=0, shift=-1.5707963267948966, value=0.304747-0.952433j
# radius=0, shift=-1.5707963267948966, value=-0.968814-0.247788j
# radius=0, shift=-1.5707963267948966, value=-0.420928+0.907094j
# radius=0, shift=-1.5707963267948966, value=-0.012504+0.999922j
# radius=0, shift=-1.5707963267948966, value=-0.985376-0.170394j
# radius=0, shift=-1.5707963267948966, value=-0.886746-0.462256j
# radius=0, shift=-1.5707963267948966, value=-0.861032-0.508551j
# radius=0, shift=-1.5707963267948966, value=-0.903224-0.429170j
# radius=0, shift=-1.5707963267948966, value=-0.842767-0.538278j

# %%
ec = loader.load("../sample_imgs/ec.png")

plt.imshow(ec)

tracker.match(ec)
tracker.show_result("EC")
# Out:
# radius=0, shift=-1.5707963267948966, value=0.924913+0.380180j

# %%
ec = loader.load("../sample_imgs/ec_tilted.png")

plt.imshow(ec)

tracker.match(ec)
tracker.show_result("EC_tilted")
# Out:
# radius=0, shift=-1.5707963267948966, value=0.953717-0.300705j

# %%
ec = loader.load("../sample_imgs/e_3.png")

plt.imshow(ec)

tracker.match(ec)
tracker.show_result("E_3")
# Out:
# radius=0, shift=-1.5707963267948966, value=-0.783343+0.621589j

# %%
ec = loader.load("../sample_imgs/e_4.png")

plt.imshow(ec)
tracker.match(ec)
tracker.show_result("E_4")
# Out:
# radius=0, shift=-1.5707963267948966, value=0.789739+0.613443j

# %%
blacks = np.zeros_like(ec)
tracker.match(blacks)
tracker.show_result("Black")
# Out:
# radius=0, shift=-1.5707963267948966, value=-1.000000+0.000000j

# %%
plt.imshow(ect.norm_minmax(np.abs(tracker.ect_template), 0, 255))
