# %%
import tracker as tr

radius = 200
offset = radius/20
ect_offset = radius/10

loader = tr.FilepathLoader(
    radius=radius,
    offset=offset
)

matcher = tr.BasicMatcher(
    bp_thresh = 0.1
)

tracker = tr.BasicTracker(
    template_path="../tracker_tests/1_template.png",
    radius = radius,
    offset = offset,
    ect_offset = ect_offset,
    matcher = matcher
)

tracker.setup()

# %% [markdown]
# ### Scaling with center in fovea

# %%
fpaths = [
    "../tracker_tests/1_scaled_50.png",
    "../tracker_tests/1_scaled_60.png",
    "../tracker_tests/1_scaled_70.png",
    "../tracker_tests/1_scaled_80.png",
    "../tracker_tests/1_scaled_90.png",
    "../tracker_tests/1_template.png",
    "../tracker_tests/1_scaled_110.png",
    "../tracker_tests/1_scaled_120.png",
]

for fpath in fpaths:

    image = loader.load(fpath)
    tracker.match(image)
    tracker.show_result(fpath.split("/")[-1])
# Out:
# radius=0, shift=-1.5707963267948966, value=-0.755932-0.654650j
# radius=0, shift=-1.5707963267948966, value=0.101336+0.994852j
# radius=0, shift=-1.5707963267948966, value=-0.979970+0.199146j
# radius=0, shift=-1.5707963267948966, value=0.182948-0.983123j
# radius=0, shift=-1.5707963267948966, value=0.890374-0.455229j
# radius=0, shift=-1.5707963267948966, value=1.000000+0.000000j
# radius=0, shift=-1.5707963267948966, value=-0.762607-0.646863j
# radius=0, shift=-1.5707963267948966, value=0.567995-0.823032j

# %% [markdown]
# ### Rotating with center in fovea

# %%
fpaths = [
    "../tracker_tests/1_template.png",
    "../tracker_tests/1_rotated_30.png",
    "../tracker_tests/1_rotated_60.png",
    "../tracker_tests/1_rotated_90.png",
    "../tracker_tests/1_rotated_120.png",
    "../tracker_tests/1_rotated_150.png",
    "../tracker_tests/1_rotated_180.png",
]

for fpath in fpaths:

    image = loader.load(fpath)
    tracker.match(image)
    tracker.show_result(fpath.split("/")[-1])
# Out:
# radius=0, shift=-1.5707963267948966, value=1.000000+0.000000j
# radius=0, shift=-1.5707963267948966, value=0.478189-0.878257j
# radius=0, shift=-1.5707963267948966, value=0.414856-0.909887j
# radius=0, shift=-1.5707963267948966, value=-0.975838-0.218495j
# radius=1, shift=-1.5707963267948966, value=0.404461+0.914555j
# radius=0, shift=-1.5707963267948966, value=-0.109399+0.993998j
# radius=0, shift=-1.5707963267948966, value=-0.825532+0.564355j

# %% [markdown]
# ### Shifting image

# %%
fpaths = [
    "../tracker_tests/1_shift_25_0.png",
    "../tracker_tests/1_template.png",
    "../tracker_tests/1_shift_-25_0.png",
    "../tracker_tests/1_shift_-50_0.png",
    "../tracker_tests/1_shift_0_-25.png",
    "../tracker_tests/1_shift_0_-50.png",
    "../tracker_tests/1_shift_0_-75.png",
    "../tracker_tests/1_shift_0_-100.png",
    "../tracker_tests/1_shift_-50_-100.png",
    "../tracker_tests/1_shift_-50_-50.png",
]

for fpath in fpaths:

    image = loader.load(fpath)
    tracker.match(image)
    tracker.show_result(fpath.split("/")[-1])
# Out:
# radius=0, shift=-1.5707963267948966, value=-0.914172+0.405327j
# radius=0, shift=-1.5707963267948966, value=1.000000+0.000000j
# radius=0, shift=-1.5707963267948966, value=-0.766980-0.641671j
# radius=0, shift=-1.5707963267948966, value=0.546191+0.837661j
# radius=0, shift=-1.5707963267948966, value=0.922173+0.386778j
# radius=0, shift=-1.5707963267948966, value=0.901065+0.433685j
# radius=0, shift=-1.5707963267948966, value=0.783332+0.621604j
# radius=0, shift=-1.5707963267948966, value=0.738559+0.674188j
# radius=0, shift=-1.5707963267948966, value=-0.124946+0.992164j
# radius=0, shift=-1.5707963267948966, value=0.247716+0.968833j
