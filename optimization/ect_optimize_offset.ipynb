# %%
import ect
import matplotlib.pyplot as plt
import numpy as np
import cv2
import scipy.optimize as optim
from numpy.random import rand

from typing import Callable

from ect_optim import ECTOffsetOptimizer

global_radius = 200
global_offset = 20

# %%
source_path = "../sample_imgs/black_e.png"

source_img = cv2.imread(source_path)
source_img = cv2.cvtColor(source_img, cv2.COLOR_BGR2GRAY)
source_img = cv2.resize(source_img, None, None, fx=0.5, fy=0.5)

plt.imshow(source_img)

# %%
def rms(x: np.ndarray) -> float:
    rms_ = np.sqrt((x*np.conj(x)).sum().sum())
    return rms_

def rmsnorm(x: np.ndarray) -> np.ndarray:
    rms = np.sqrt((x*np.conj(x)).sum().sum())
    return x/rms

def snr(image: cv2.Mat, template: cv2.Mat):
    snr_lin = (1/rms((rmsnorm(image) - rmsnorm(template))))
    return 20*np.log(snr_lin)

# %%
blacke = ECTOffsetOptimizer(
    image_path = "../sample_imgs/black_e.png",
    radius = global_radius,
    img_offset = global_offset,
    loss_fcn = lambda x, y: -snr(x, y)
)

print(f"{blacke.loss([45])=}")
print(f"{blacke.loss_sidelobe([45])=}")

blacke.show_result(rmsnorm, 45)
# Out:
# blacke.loss([45])=-11.608628536703158
# blacke.loss_sidelobe([45])=-18.08255808838154

# %%
result = blacke.optim(method = "Nelder-Mead")

solution = result['x'][0]
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=24.43, loss=0.78
# ect_offset=28.68, loss=-1.80
# ect_offset=37.17, loss=-8.81
# ect_offset=45.67, loss=-11.32
# ect_offset=41.42, loss=-11.68
# ect_offset=43.55, loss=-12.25
# ect_offset=43.55, loss=-12.25
# ect_offset=43.02, loss=-12.26
# ect_offset=43.02, loss=-12.26
# ect_offset=43.15, loss=-12.26
# ect_offset=43.08, loss=-12.26
# ect_offset=43.08, loss=-12.26
# ect_offset=43.10, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26

# %%
blacke.show_result(solution, rmsnorm)

print(f"{blacke.loss([solution])=}")
print(f"{blacke.loss_sidelobe([solution])=}")
# Out:
# blacke.loss([solution])=-12.25892529982934
# blacke.loss_sidelobe([solution])=-17.562519969913396

# %%
dupa = ECTOffsetOptimizer(
    image_path = "../sample_imgs/dupa.png",
    radius = global_radius,
    img_offset = global_offset,
    loss_fcn = lambda x, y: -snr(x, y)
)

result = dupa.optim(method = "Nelder-Mead")

solution = result['x'][0]
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=38.08, loss=-7.84
# ect_offset=44.70, loss=-9.28
# ect_offset=51.32, loss=-9.54
# ect_offset=48.01, loss=-9.67
# ect_offset=48.01, loss=-9.67
# ect_offset=48.84, loss=-9.95
# ect_offset=48.84, loss=-9.95
# ect_offset=48.84, loss=-9.95
# ect_offset=48.84, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.80, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95
# ect_offset=48.79, loss=-9.95

# %%
dupa.show_result(solution, rmsnorm)

print(f"{dupa.loss([solution])=}")
print(f"{dupa.loss_sidelobe([solution])=}")
# Out:
# dupa.loss([solution])=-9.947884743277044
# dupa.loss_sidelobe([solution])=-11.012513395088703

# %%
stripes = ECTOffsetOptimizer(
    image_path = "../sample_imgs/stripes3.png",
    radius = global_radius,
    img_offset = global_offset,
    loss_fcn = lambda x, y: -snr(x, y)
)

result = stripes.optim(method = "Nelder-Mead")

solution = result['x'][0]
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=39.47, loss=-4.30
# ect_offset=39.47, loss=-4.30
# ect_offset=39.47, loss=-4.30
# ect_offset=39.59, loss=-4.40
# ect_offset=39.59, loss=-4.40
# ect_offset=39.59, loss=-4.40
# ect_offset=39.59, loss=-4.40
# ect_offset=39.58, loss=-4.41
# ect_offset=39.58, loss=-4.41
# ect_offset=39.59, loss=-4.41
# ect_offset=39.59, loss=-4.41
# ect_offset=39.59, loss=-4.41
# ect_offset=39.59, loss=-4.41
# ect_offset=39.59, loss=-4.41
# ect_offset=39.59, loss=-4.41
# ect_offset=39.59, loss=-4.41

# %%
stripes.show_result(solution, rmsnorm)

print(f"{stripes.loss([solution])=}")
print(f"{stripes.loss_sidelobe([solution])=}")
# Out:
# stripes.loss([solution])=-4.405237567804928
# stripes.loss_sidelobe([solution])=-5.512215467209427

# %%
stripes2 = ECTOffsetOptimizer(
    image_path = "../sample_imgs/stripes2.jpeg",
    radius = global_radius,
    img_offset = global_offset,
    loss_fcn = lambda x, y: -snr(x, y)
)

result = stripes2.optim(method = "Nelder-Mead")

solution = result['x'][0]
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=36.58, loss=-6.17
# ect_offset=42.94, loss=-7.00
# ect_offset=49.30, loss=-7.27
# ect_offset=49.30, loss=-7.27
# ect_offset=49.30, loss=-7.27
# ect_offset=49.30, loss=-7.27
# ect_offset=48.91, loss=-7.34
# ect_offset=48.91, loss=-7.34
# ect_offset=49.01, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.97, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34
# ect_offset=48.96, loss=-7.34

# %%
stripes2.show_result(solution, rmsnorm)

print(f"{stripes2.loss([solution])=}")
print(f"{stripes2.loss_sidelobe([solution])=}")
# Out:
# stripes2.loss([solution])=-7.337438843164541
# stripes2.loss_sidelobe([solution])=-7.716157701907043

# %%
text = ECTOffsetOptimizer(
    image_path = "../sample_imgs/text.png",
    radius = global_radius,
    img_offset = global_offset,
    loss_fcn = lambda x, y: -snr(x, y)
)

result = text.optim(method = "Nelder-Mead")

solution = result["x"][0]
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=35.76, loss=-6.43
# ect_offset=41.98, loss=-8.42
# ect_offset=48.20, loss=-9.03
# ect_offset=48.20, loss=-9.03
# ect_offset=48.20, loss=-9.03
# ect_offset=47.42, loss=-9.10
# ect_offset=47.42, loss=-9.10
# ect_offset=47.04, loss=-9.28
# ect_offset=47.04, loss=-9.28
# ect_offset=47.04, loss=-9.28
# ect_offset=47.08, loss=-9.28
# ect_offset=47.06, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28
# ect_offset=47.07, loss=-9.28

# %%
text.show_result(solution, rmsnorm)

print(f"{text.loss([solution])=}")
print(f"{text.loss_sidelobe([solution])=}")
# Out:
# text.loss([solution])=-9.28241259551539
# text.loss_sidelobe([solution])=-10.301713358846643

# %%
dupa.optim()
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=14.07, loss=4.35
# ect_offset=39.25, loss=-8.21
# ect_offset=58.63, loss=-9.11
# ect_offset=58.79, loss=-9.34
# ect_offset=58.84, loss=-9.36
# ect_offset=58.85, loss=-9.36
# ect_offset=58.85, loss=-9.36
# ect_offset=58.85, loss=-9.36
#       fun: -9.36244556787537
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.24344968e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 48
#       nit: 8
#      njev: 24
#    status: 0
#   success: True
#         x: array([58.84919325])

# %%
stripes.optim()
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=43.19, loss=-4.55
# ect_offset=43.18, loss=-4.55
# ect_offset=43.18, loss=-4.55
#       fun: -4.55062020282053
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-1.86517453e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 14
#       nit: 3
#      njev: 7
#    status: 0
#   success: True
#         x: array([43.18494032])

# %%
blacke.optim()
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=47.42, loss=-10.14
# ect_offset=42.09, loss=-12.04
# ect_offset=43.91, loss=-12.19
# ect_offset=43.26, loss=-12.26
# ect_offset=43.20, loss=-12.26
# ect_offset=43.07, loss=-12.26
# ect_offset=43.10, loss=-12.26
# ect_offset=43.09, loss=-12.26
# ect_offset=43.09, loss=-12.26
#       fun: -12.258925299837415
#  hess_inv: <1x1 LbfgsInvHessProduct with dtype=float64>
#       jac: array([-2.13162803e-06])
#   message: 'CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL'
#      nfev: 20
#       nit: 9
#      njev: 10
#    status: 0
#   success: True
#         x: array([43.09151823])

# %%
# turns out, best ect_offset is around radius/5

# %%
shrek = ECTOffsetOptimizer(
    image_path = "../sample_imgs/shrek.png",
    radius=100,
    img_offset=10,
    loss_fcn=lambda x,y: -snr(x, y)
)

solution = shrek.optim(method = "Nelder-Mead")
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=4.44, loss=5.03
# ect_offset=5.21, loss=4.89
# ect_offset=6.75, loss=4.27
# ect_offset=9.84, loss=2.58
# ect_offset=16.02, loss=-1.67
# ect_offset=22.19, loss=-2.85
# ect_offset=22.19, loss=-2.85
# ect_offset=25.28, loss=-4.51
# ect_offset=25.28, loss=-4.51
# ect_offset=25.28, loss=-4.51
# ect_offset=25.28, loss=-4.51
# ect_offset=25.09, loss=-5.28
# ect_offset=25.09, loss=-5.28
# ect_offset=25.09, loss=-5.28
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29
# ect_offset=25.11, loss=-5.29

# %%
solution = solution["x"]
shrek.show_result(solution, rmsnorm)

print(f"{shrek.loss([solution])=}")
print(f"{shrek.loss_sidelobe([solution])=}")
# Out:
# shrek.loss([solution])=-5.292899078603717
# shrek.loss_sidelobe([solution])=-6.101603491474156

# %%
inv_img = ect.ilogpolar(ect.complex_to_hsv(shrek.inv), radius=200, offset=20)

plt.figure(figsize=(10,10))
plt.imshow(inv_img)

# %%
# result = shrek.optim(sidelobe=True, method="Nelder-Mead")

# solution = result["x"]
# Out:
# /tmp/ipykernel_4124/1856333479.py:88: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   result = optim.minimize(
# ect_offset=23.96, loss=0.75
# ect_offset=28.12, loss=-1.62
# ect_offset=36.45, loss=-5.59
# ect_offset=53.12, loss=-6.83
# ect_offset=53.12, loss=-6.83
# ect_offset=53.12, loss=-6.83
# ect_offset=57.29, loss=-5.54
# ect_offset=57.29, loss=-5.54
# ect_offset=59.37, loss=-5.08
# ect_offset=59.37, loss=-5.08
# ect_offset=59.37, loss=-5.08
# ect_offset=59.11, loss=-5.65
# ect_offset=59.11, loss=-5.65
# ect_offset=59.17, loss=-5.64
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ect_offset=59.14, loss=-5.65
# ...

# %%
# shrek.show_result(solution, rmsnorm)

# print(f"{shrek.loss_sidelobe([solution])=}")
# Out:
# shrek.loss_sidelobe([solution])=-9.747944531833896
